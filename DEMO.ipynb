# %% [markdown]
# based on the repo structure, we could import the function from custom module like this:

# %%
from src.shared.example_module import import_checking
import_checking()
# Out:
# 'Import successful'

# %% [markdown]
# And what we actually want is to import this function by following, so it has the basis to be integrated into other applications

# %%
from shared.example_module import import_checking
import_checking()
# Out:
# 'Import successful'
